# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns 

import os
for dirname, _, filenames in os.walk('/content/Dataset'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# ### Loading the Dataset

# %%
Matches = pd.read_csv("IPL Matches 2008-2020.csv",index_col='id')
Matches.head()
# Out:
#               city        date player_of_match  \
# id
# 335982   Bangalore  2008-04-18     BB McCullum
# 335983  Chandigarh  2008-04-19      MEK Hussey
# 335984       Delhi  2008-04-19     MF Maharoof
# 335985      Mumbai  2008-04-20      MV Boucher
# 335986     Kolkata  2008-04-20       DJ Hussey
#
#                                              venue  neutral_venue  \
# id
# 335982                       M Chinnaswamy Stadium              0
# 335983  Punjab Cricket Association Stadium, Mohali              0
# 335984                            Feroz Shah Kotla              0
# 335985                            Wankhede Stadium              0
# 335986                                Eden Gardens              0
#
#                               team1                        team2  \
# id
# 335982  Royal Challengers Bangalore        Kolkata Knight Riders
# 335983              Kings XI Punjab          Chennai Super Kings
# 335984             Delhi Daredevils             Rajasthan Royals
# 335985               Mumbai Indians  Royal Challengers Bangalore
# 335986        Kolkata Knight Riders              Deccan Chargers
#
#                         toss_winner toss_decision  \
# id
# 335982  Royal Challengers Bangalore         field
# 335983          Chennai Super Kings           bat
# 335984             Rajasthan Royals           bat
# 335985               Mumbai Indians           bat
# 335986              Deccan Chargers           bat
#
#                              winner   result  result_margin eliminator method  \
# id
# 335982        Kolkata Knight Riders     runs         140.00          N    NaN
# 335983          Chennai Super Kings     runs          33.00          N    NaN
# 335984             Delhi Daredevils  wickets           9.00          N    NaN
# 335985  Royal Challengers Bangalore  wickets           5.00          N    NaN
# 335986        Kolkata Knight Riders  wickets           5.00          N    NaN
#
#           umpire1         umpire2
# id
# 335982  Asad Rauf     RE Koertzen
# 335983  MR Benson      SL Shastri
# 335984  Aleem Dar  GA Pratapkumar
# 335985   SJ Davis       DJ Harper
# 335986  BF Bowden     K Hariharan

# %% [markdown]
# ### Preprocess the dataframe

# %%
Matches.info()
Matches.columns
Matches.describe()
Matches.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 816 entries, 335982 to 1237181
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   city             803 non-null    object
#  1   date             816 non-null    object
#  2   player_of_match  812 non-null    object
#  3   venue            816 non-null    object
#  4   neutral_venue    816 non-null    int64
#  5   team1            816 non-null    object
#  6   team2            816 non-null    object
#  7   toss_winner      816 non-null    object
#  8   toss_decision    816 non-null    object
#  9   winner           812 non-null    object
#  10  result           812 non-null    object
#  11  result_margin    799 non-null    float64
#  12  eliminator       812 non-null    object
#  13  method           19 non-null     object
#  14  umpire1          816 non-null    object
#  15  umpire2          816 non-null    object
# dtypes: float64(1), int64(1), object(14)
# memory usage: 108.4+ KB
#               city        date player_of_match  \
# id
# 335982   Bangalore  2008-04-18     BB McCullum
# 335983  Chandigarh  2008-04-19      MEK Hussey
# 335984       Delhi  2008-04-19     MF Maharoof
# 335985      Mumbai  2008-04-20      MV Boucher
# 335986     Kolkata  2008-04-20       DJ Hussey
# 335987      Jaipur  2008-04-21       SR Watson
# 335988   Hyderabad  2008-04-22        V Sehwag
# 335989     Chennai  2008-04-23       ML Hayden
# 335990   Hyderabad  2008-04-24       YK Pathan
# 335991  Chandigarh  2008-04-25   KC Sangakkara
#
#                                              venue  neutral_venue  \
# id
# 335982                       M Chinnaswamy Stadium              0
# 335983  Punjab Cricket Association Stadium, Mohali              0
# 335984                            Feroz Shah Kotla              0
# 335985                            Wankhede Stadium              0
# 335986                                Eden Gardens              0
# 335987                      Sawai Mansingh Stadium              0
# 335988   Rajiv Gandhi International Stadium, Uppal              0
# 335989             MA Chidambaram Stadium, Chepauk              0
# 335990   Rajiv Gandhi International Stadium, Uppal              0
# 335991  Punjab Cricket Association Stadium, Mohali              0
#
#                               team1                        team2  \
# id
# 335982  Royal Challengers Bangalore        Kolkata Knight Riders
# 335983              Kings XI Punjab          Chennai Super Kings
# 335984             Delhi Daredevils             Rajasthan Royals
# 335985               Mumbai Indians  Royal Challengers Bangalore
# 335986        Kolkata Knight Riders              Deccan Chargers
# 335987             Rajasthan Royals              Kings XI Punjab
# 335988              Deccan Chargers             Delhi Daredevils
# 335989          Chennai Super Kings               Mumbai Indians
# 335990              Deccan Chargers             Rajasthan Royals
# 335991              Kings XI Punjab               Mumbai Indians
#
#                         toss_winner toss_decision  \
# id
# 335982  Royal Challengers Bangalore         field
# 335983          Chennai Super Kings           bat
# 335984             Rajasthan Royals           bat
# 335985               Mumbai Indians           bat
# 335986              Deccan Chargers           bat
# 335987              Kings XI Punjab           bat
# 335988              Deccan Chargers           bat
# 335989               Mumbai Indians         field
# 335990             Rajasthan Royals         field
# 335991               Mumbai Indians         field
#
#                              winner   result  result_margin eliminator method  \
# id
# 335982        Kolkata Knight Riders     runs         140.00          N    NaN
# 335983          Chennai Super Kings     runs          33.00          N    NaN
# 335984             Delhi Daredevils  wickets           9.00          N    NaN
# 335985  Royal Challengers Bangalore  wickets           5.00          N    NaN
# 335986        Kolkata Knight Riders  wickets           5.00          N    NaN
# 335987             Rajasthan Royals  wickets           6.00          N    NaN
# 335988             Delhi Daredevils  wickets           9.00          N    NaN
# 335989          Chennai Super Kings     runs           6.00          N    NaN
# 335990             Rajasthan Royals  wickets           3.00          N    NaN
# 335991              Kings XI Punjab     runs          66.00          N    NaN
#
#           umpire1         umpire2
# id
# 335982  Asad Rauf     RE Koertzen
# 335983  MR Benson      SL Shastri
# 335984  Aleem Dar  GA Pratapkumar
# 335985   SJ Davis       DJ Harper
# 335986  BF Bowden     K Hariharan
# 335987  Aleem Dar       RB Tiffin
# 335988  IL Howell       AM Saheba
# 335989  DJ Harper  GA Pratapkumar
# 335990  Asad Rauf       MR Benson
# 335991  Aleem Dar       AM Saheba

# %% [markdown]
# ## Deleting Method which is not useful

# %%
Matches.loc[Matches.method.notnull()]
Matches.drop(['method'],axis=1, inplace=True)
Matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 816 entries, 335982 to 1237181
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   city             803 non-null    object
#  1   date             816 non-null    object
#  2   player_of_match  812 non-null    object
#  3   venue            816 non-null    object
#  4   neutral_venue    816 non-null    int64
#  5   team1            816 non-null    object
#  6   team2            816 non-null    object
#  7   toss_winner      816 non-null    object
#  8   toss_decision    816 non-null    object
#  9   winner           812 non-null    object
#  10  result           812 non-null    object
#  11  result_margin    799 non-null    float64
#  12  eliminator       812 non-null    object
#  13  umpire1          816 non-null    object
#  14  umpire2          816 non-null    object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 102.0+ KB

# %% [markdown]
# ## Pie Graph on Winner Team

# %%
# win_team=pd.DataFrame({'winner':Matches['winner']})
# count_wins=win_team.value_counts()
# labels=[X[0] for X in count_wins.keys()]
# labels=count_wins.keys()
fig=plt.figure(figsize=(20,12))
ax=fig.add_subplot(111)
ax.set(title='Most wins in IPL')
#plt.pie(x=count_wins,autopct='%.1f%%',labels=labels)
plt.pie(x=Matches['winner'].value_counts(),autopct='%.1f%%',labels=Matches['winner'].value_counts().index)
plt.show()

# %% [markdown]
# ## Most wins in Eliminator
#
# ### Select two columns with conditional values

# %%
Matches[['winner','eliminator']] [Matches['eliminator']=='Y'].value_counts()
# Out:
# winner                       eliminator
# Kings XI Punjab              Y             3
# Delhi Capitals               Y             2
# Mumbai Indians               Y             2
# Rajasthan Royals             Y             2
# Royal Challengers Bangalore  Y             2
# Kolkata Knight Riders        Y             1
# Sunrisers Hyderabad          Y             1
# dtype: int64

# %%
sns.countplot(data=Matches[Matches['eliminator']=='Y'], x='winner')
plt.title('Most wins in Eliminator')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Top 10 Famous Venue

# %%
Matches['venue'].value_counts()
# Out:
# Eden Gardens                                            77
# Feroz Shah Kotla                                        74
# Wankhede Stadium                                        73
# M Chinnaswamy Stadium                                   65
# Rajiv Gandhi International Stadium, Uppal               64
# MA Chidambaram Stadium, Chepauk                         57
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Dubai International Cricket Stadium                     33
# Sheikh Zayed Stadium                                    29
# Punjab Cricket Association IS Bindra Stadium, Mohali    21
# Maharashtra Cricket Association Stadium                 21
# Sharjah Cricket Stadium                                 18
# Dr DY Patil Sports Academy                              17
# Subrata Roy Sahara Stadium                              17
# M.Chinnaswamy Stadium                                   15
# Kingsmead                                               15
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     13
# Sardar Patel Stadium, Motera                            12
# SuperSport Park                                         12
# Brabourne Stadium                                       11
# Saurashtra Cricket Association Stadium                  10
# Himachal Pradesh Cricket Association Stadium             9
# Holkar Cricket Stadium                                   9
# New Wanderers Stadium                                    8
# Barabati Stadium                                         7
# Newlands                                                 7
# St George's Park                                         7
# JSCA International Stadium Complex                       7
# Shaheed Veer Narayan Singh International Stadium         6
# Nehru Stadium                                            5
# Green Park                                               4
# Buffalo Park                                             3
# Vidarbha Cricket Association Stadium, Jamtha             3
# De Beers Diamond Oval                                    3
# OUTsurance Oval                                          2
# Name: venue, dtype: int64

# %%
sns.barplot(x=Matches['venue'].value_counts().head(10),y=Matches['venue'].value_counts().head(10).index)
plt.title('Famous Venues')
plt.xlabel('Venue Count')
plt.ylabel('Venue')
# Out:
# Text(0, 0.5, 'Venue')

# %% [markdown]
# ## Top 5 Umpire 1 & Umpire 2

# %%
Matches['umpire1'].value_counts()
# Out:
# HDPK Dharmasena          78
# AK Chaudhary             56
# Asad Rauf                51
# M Erasmus                40
# Aleem Dar                38
# BF Bowden                37
# S Ravi                   37
# BR Doctrove              34
# CB Gaffaney              34
# KN Ananthapadmanabhan    33
# AY Dandekar              28
# C Shamshuddin            22
# NJ Llong                 21
# Nitin Menon              20
# RE Koertzen              20
# S Asnani                 19
# VA Kulkarni              19
# BNJ Oxenford             16
# JD Cloete                16
# YC Barde                 14
# A Nand Kishore           14
# BG Jerling               13
# RK Illingworth           13
# SS Hazare                11
# S Das                    10
# MR Benson                10
# K Hariharan              10
# DJ Harper                 9
# UV Gandhe                 8
# CK Nandan                 8
# IL Howell                 7
# GAV Baxter                7
# RM Deshpande              7
# SJ Davis                  6
# VK Sharma                 6
# SD Fry                    5
# RJ Tucker                 5
# A Deshmukh                5
# PR Reiffel                5
# SK Tarapore               5
# PG Pathak                 4
# IJ Gould                  3
# K Bharatan                3
# AM Saheba                 3
# AV Jayaprakash            2
# K Srinath                 2
# SJA Taufel                1
# SL Shastri                1
# Name: umpire1, dtype: int64

# %%
sns.barplot(x=Matches['umpire1'].value_counts().head(5).index,y=Matches['umpire1'].value_counts().head(5))
plt.title('Top 5 Umpire1')
plt.xticks(rotation=45)
plt.xlabel('Matches Count')
plt.ylabel('Umpire1')
# Out:
# Text(0, 0.5, 'Umpire1')

# %%
Matches['umpire2'].value_counts()
# Out:
# S Ravi             84
# C Shamshuddin      60
# SJA Taufel         54
# CK Nandan          49
# RJ Tucker          41
# Nitin Menon        37
# BNJ Oxenford       32
# VA Kulkarni        31
# AK Chaudhary       31
# RB Tiffin          30
# SK Tarapore        26
# M Erasmus          25
# AM Saheba          23
# RE Koertzen        21
# VK Sharma          20
# PR Reiffel         19
# DJ Harper          18
# RK Illingworth     18
# HDPK Dharmasena    16
# NJ Llong           16
# CB Gaffaney        13
# SL Shastri         13
# K Srinath          13
# K Hariharan        11
# A Nand Kishore     11
# S Asnani           11
# BR Doctrove         8
# PG Pathak           7
# A Deshmukh          7
# IL Howell           7
# K Srinivasan        6
# AL Hill             6
# SS Hazare           6
# I Shivram           6
# GA Pratapkumar      6
# S Das               5
# TH Wijewardene      5
# YC Barde            5
# BG Jerling          4
# AV Jayaprakash      4
# IJ Gould            3
# SD Ranade           2
# MR Benson           2
# Subroto Das         1
# JD Cloete           1
# SJ Davis            1
# SD Fry              1
# Name: umpire2, dtype: int64

# %%
sns.barplot(x=Matches['umpire2'].value_counts().head(5).index,y=Matches['umpire2'].value_counts().head(5))
plt.title('Top 5 Umpire2')
plt.xticks(rotation=45)
plt.xlabel('Matches Count')
plt.ylabel('Umpire2')
# Out:
# Text(0, 0.5, 'Umpire2')
